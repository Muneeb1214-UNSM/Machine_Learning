# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
data = pd.read_csv('2014.csv')

# %%
flights = sns.load_dataset('flights')

# %%
iris = sns.load_dataset('iris')

# %% [markdown]
# SCATTERPLOT(NUMERICAL-NUMERICAL)

# %%
data.head()
# Out:
#   REF_AREA Territorio        F        M  OBS_VALUE
# 0    ITC11     Torino  1183716  1101620    2285336
# 1    ITC12   Vercelli    91714    84993     176707
# 2    ITC15     Novara   191309   178946     370255
# 3    ITC16      Cuneo   301543   291257     592800
# 4    ITC17       Asti   113264   106847     220111

# %%
x = "F"
y = "m"

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df['total_bill'], y=df['tip'],hue=df['sex'],style=df['smoker'],size=df['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=data['F'], y=data['M'])
# Out:
# <Axes: xlabel='F', ylabel='M'>

# %% [markdown]
# BARPLOT(NUMERICAL_CATEGORICAL)

# %%
data.head()
# Out:
#   REF_AREA Territorio        F        M  OBS_VALUE
# 0    ITC11     Torino  1183716  1101620    2285336
# 1    ITC12   Vercelli    91714    84993     176707
# 2    ITC15     Novara   191309   178946     370255
# 3    ITC16      Cuneo   301543   291257     592800
# 4    ITC17       Asti   113264   106847     220111

# %%
sns.barplot(x=data['Territorio'],y=data['M'])
# Out:
# <Axes: xlabel='Territorio', ylabel='M'>

# %% [markdown]
# BOXPLOT(NUMERICAL_CATEGORICAL)

# %%
sns.boxplot(x=data['Territorio'],y=data['M'])
# Out:
# <Axes: xlabel='Territorio', ylabel='M'>

# %% [markdown]
# DISTPLOT(NUMERICAL_CATEGORICAL)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(df[df['sex']==0]['size'],hist=False)
sns.distplot(df[df['sex']==1]['size'],hist=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2688\3183101446.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['sex']==0]['size'],hist=False)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\distributions.py:2464: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\User\anaconda3\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\User\AppData\Local\Temp\ipykernel_2688\3183101446.py:2: UserWarning:
#
# ...

# %% [markdown]
# HEATMAP(CATEGORICAL - CATEGORICAL)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.heatmap(pd.crosstab(df['sex'],df['day']))
# Out:
# <Axes: xlabel='day', ylabel='sex'>

# %% [markdown]
# CLUSTERMAP(CATEGORICAL - CATEGORICAL)

# %%
sns.clustermap(pd.crosstab(df['sex'],df['day']))

# %% [markdown]
# PAIRPLOT(DISPLAYA ALL NUMERICAL COLUMNS IN THE FORM OF SCATTER PLOTS COMBINE)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# LINEPLOT(NUMERICAL - NUMERICAL)

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.lineplot(x = flights['year'], y = flights['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2688\2230379170.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# <Axes: xlabel='year', ylabel='month'>
